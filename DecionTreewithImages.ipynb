# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dt=pd.read_csv("Social_Network_Ads.csv")
dt=dt.drop(['User ID','Gender'],axis=1)
dt.head(5)
# Out:
#     Age  EstimatedSalary  Purchased
# 0  19.0          19000.0          0
# 1  35.0          20000.0          0
# 2  26.0          43000.0          0
# 3  27.0          57000.0          0
# 4  19.0          76000.0          0

# %%
X=dt.iloc[:,:-1].values
y=dt.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.fit_transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier(criterion='entropy',random_state=0)
dc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
y_pred=dc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[46, 11],
#        [ 1, 22]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.85

# %%
from sklearn import tree

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(dc,filled=True)
# Out:
# [Text(406.51171875, 526.6125000000001, 'X[0] <= 0.449\nentropy = 0.954\nsamples = 320\nvalue = [200, 120]'),
#  Text(244.125, 492.63750000000005, 'X[1] <= 0.579\nentropy = 0.675\nsamples = 225\nvalue = [185, 40]'),
#  Text(156.9375, 458.6625, 'X[0] <= -0.113\nentropy = 0.275\nsamples = 190\nvalue = [181, 9]'),
#  Text(139.5, 424.6875, 'entropy = 0.0\nsamples = 129\nvalue = [129, 0]'),
#  Text(174.375, 424.6875, 'X[1] <= -0.094\nentropy = 0.604\nsamples = 61\nvalue = [52, 9]'),
#  Text(156.9375, 390.7125, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(191.8125, 390.7125, 'X[1] <= 0.374\nentropy = 0.881\nsamples = 30\nvalue = [21, 9]'),
#  Text(174.375, 356.7375, 'X[0] <= 0.355\nentropy = 0.811\nsamples = 28\nvalue = [21, 7]'),
#  Text(139.5, 322.76250000000005, 'X[1] <= -0.007\nentropy = 0.738\nsamples = 24\nvalue = [19, 5]'),
#  Text(122.0625, 288.7875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(156.9375, 288.7875, 'X[0] <= 0.262\nentropy = 0.667\nsamples = 23\nvalue = [19, 4]'),
#  Text(139.5, 254.8125, 'X[1] <= 0.257\nentropy = 0.764\nsamples = 18\nvalue = [14, 4]'),
#  Text(122.0625, 220.83750000000003, 'X[1] <= 0.228\nentropy = 0.837\nsamples = 15\nvalue = [11, 4]'),
#  Text(104.625, 186.8625, 'X[1] <= 0.198\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]'),
#  Text(69.75, 152.8875, 'X[0] <= 0.074\nentropy = 0.65\nsamples = 12\nvalue = [10, 2]'),
#  Text(52.3125, 118.91250000000002, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(87.1875, 118.91250000000002, 'X[1] <= 0.154\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(69.75, 84.9375, 'X[0] <= 0.168\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(34.875, 50.96249999999998, 'X[1] <= 0.067\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(17.4375, 16.987499999999955, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(52.3125, 16.987499999999955, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(104.625, 50.96249999999998, 'X[1] <= 0.067\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(87.1875, 16.987499999999955, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(122.0625, 16.987499999999955, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(104.625, 84.9375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(139.5, 152.8875, 'X[0] <= 0.074\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(122.0625, 118.91250000000002, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(156.9375, 118.91250000000002, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(139.5, 186.8625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(156.9375, 220.83750000000003, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(174.375, 254.8125, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(209.25, 322.76250000000005, 'X[1] <= 0.023\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(191.8125, 288.7875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(226.6875, 288.7875, 'X[1] <= 0.169\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(209.25, 254.8125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(244.125, 254.8125, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(209.25, 356.7375, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(331.3125, 458.6625, 'X[1] <= 1.413\nentropy = 0.513\nsamples = 35\nvalue = [4, 31]'),
#  Text(313.875, 424.6875, 'X[1] <= 1.135\nentropy = 0.742\nsamples = 19\nvalue = [4, 15]'),
#  Text(296.4375, 390.7125, 'entropy = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(331.3125, 390.7125, 'X[0] <= -0.863\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(313.875, 356.7375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(348.75, 356.7375, 'X[1] <= 1.37\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(331.3125, 322.76250000000005, 'X[0] <= -0.394\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(296.4375, 288.7875, 'X[1] <= 1.296\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(279.0, 254.8125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(313.875, 254.8125, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(366.1875, 288.7875, 'X[1] <= 1.223\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(348.75, 254.8125, 'X[0] <= -0.16\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(331.3125, 220.83750000000003, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(366.1875, 220.83750000000003, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(383.625, 254.8125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(366.1875, 322.76250000000005, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(348.75, 424.6875, 'entropy = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(568.8984375, 492.63750000000005, 'X[0] <= 0.824\nentropy = 0.629\nsamples = 95\nvalue = [15, 80]'),
#  Text(475.171875, 458.6625, 'X[1] <= -1.031\nentropy = 0.918\nsamples = 21\nvalue = [7, 14]'),
#  Text(418.5, 424.6875, 'X[1] <= -1.412\nentropy = 0.592\nsamples = 7\nvalue = [1, 6]'),
#  Text(401.0625, 390.7125, 'X[0] <= 0.73\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(383.625, 356.7375, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(418.5, 356.7375, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(435.9375, 390.7125, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(531.84375, 424.6875, 'X[1] <= 0.974\nentropy = 0.985\nsamples = 14\nvalue = [6, 8]'),
#  Text(488.25, 390.7125, 'X[1] <= -0.548\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(453.375, 356.7375, 'X[0] <= 0.637\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(435.9375, 322.76250000000005, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(470.8125, 322.76250000000005, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(523.125, 356.7375, 'X[1] <= 0.374\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(505.6875, 322.76250000000005, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(540.5625, 322.76250000000005, 'X[1] <= 0.623\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(523.125, 288.7875, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(558.0, 288.7875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(575.4375, 390.7125, 'X[1] <= 1.794\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(558.0, 356.7375, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(592.875, 356.7375, 'X[1] <= 1.911\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(575.4375, 322.76250000000005, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(610.3125, 322.76250000000005, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(662.625, 458.6625, 'X[1] <= -0.856\nentropy = 0.494\nsamples = 74\nvalue = [8, 66]'),
#  Text(645.1875, 424.6875, 'entropy = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(680.0625, 424.6875, 'X[1] <= -0.665\nentropy = 0.612\nsamples = 53\nvalue = [8, 45]'),
#  Text(645.1875, 390.7125, 'X[0] <= 2.042\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(627.75, 356.7375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(662.625, 356.7375, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(714.9375, 390.7125, 'X[0] <= 1.011\nentropy = 0.426\nsamples = 46\nvalue = [4, 42]'),
#  Text(697.5, 356.7375, 'entropy = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(732.375, 356.7375, 'X[0] <= 1.386\nentropy = 0.523\nsamples = 34\nvalue = [4, 30]'),
#  Text(680.0625, 322.76250000000005, 'X[1] <= 0.14\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(662.625, 288.7875, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(697.5, 288.7875, 'X[1] <= 0.916\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]'),
#  Text(680.0625, 254.8125, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(714.9375, 254.8125, 'X[1] <= 1.911\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(697.5, 220.83750000000003, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(732.375, 220.83750000000003, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(784.6875, 322.76250000000005, 'X[0] <= 1.948\nentropy = 0.258\nsamples = 23\nvalue = [1, 22]'),
#  Text(767.25, 288.7875, 'entropy = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(802.125, 288.7875, 'X[1] <= 0.433\nentropy = 0.544\nsamples = 8\nvalue = [1, 7]'),
#  Text(784.6875, 254.8125, 'X[0] <= 2.042\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(767.25, 220.83750000000003, 'X[1] <= 0.257\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(749.8125, 186.8625, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(784.6875, 186.8625, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(802.125, 220.83750000000003, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(819.5625, 254.8125, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]')]
